# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('C:/Users/91637/OneDrive/Desktop/EXCELAR ASSIGNMENT/14 Random Forest/glass.xlsx',sheet_name='glass')

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.shape
# Out:
# (214, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
for i in df.columns:
    print(i, df[i].isnull().sum())
# Out:
# RI 0
# Na 0
# Mg 0
# Al 0
# Si 0
# K 0
# Ca 0
# Ba 0
# Fe 0
# Type 0

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %%
df[df.duplicated()]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
df.drop_duplicates(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Loop through each column in the DataFrame
for col in df.columns:
    # Print descriptive statistics
    print(f"Statistics for '{col}':")
    print(df[col].describe(), "\n")
    
    # Set up the figure with subplots for boxplot, KDE, histogram + KDE, and violin plot
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Reduced figure size (1 row, 4 columns)

    # Box plot (1st plot)
    sns.boxplot(y=df[col], ax=axes[0], color='skyblue')
    axes[0].set_title(f'Box Plot of {col}')
    axes[0].set_ylabel(col)

    # KDE plot (2nd plot)
    sns.kdeplot(df[col], fill=True, ax=axes[1], color='salmon', linewidth=2)
    axes[1].set_title(f'KDE Plot of {col}')
    axes[1].set_xlabel(col)

    # Histogram with KDE (3rd plot)
    sns.histplot(df[col], bins=30, kde=True, ax=axes[2], color='teal')
    axes[2].set_title(f'Histogram + KDE of {col}')
    axes[2].set_xlabel(col)
    axes[2].grid(True, linestyle='--', alpha=0.5)

    # Violin plot (4th plot)
    sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
    axes[3].set_title(f'Violin Plot of {col}')
    axes[3].set_ylabel(col)

    # Adjust layout to make sure plots don't overlap
    plt.tight_layout()
    plt.show()
# Out:
# Statistics for 'RI':
# count    213.000000
# mean       1.518348
# std        0.003033
# min        1.511150
# 25%        1.516520
# 50%        1.517680
# 75%        1.519150
# max        1.533930
# Name: RI, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Na':
# count    213.000000
# mean      13.404085
# std        0.816662
# min       10.730000
# 25%       12.900000
# 50%       13.300000
# 75%       13.810000
# max       17.380000
# Name: Na, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Mg':
# count    213.000000
# mean       2.679202
# std        1.443691
# min        0.000000
# 25%        2.090000
# 50%        3.480000
# 75%        3.600000
# max        4.490000
# Name: Mg, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Al':
# count    213.000000
# mean       1.449484
# std        0.495925
# min        0.290000
# 25%        1.190000
# 50%        1.360000
# 75%        1.630000
# max        3.500000
# Name: Al, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Si':
# count    213.000000
# mean      72.655070
# std        0.773998
# min       69.810000
# 25%       72.280000
# 50%       72.790000
# 75%       73.090000
# max       75.410000
# Name: Si, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'K':
# count    213.000000
# mean       0.498873
# std        0.653185
# min        0.000000
# 25%        0.130000
# 50%        0.560000
# 75%        0.610000
# max        6.210000
# Name: K, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Ca':
# count    213.000000
# mean       8.954085
# std        1.425882
# min        5.430000
# 25%        8.240000
# 50%        8.600000
# 75%        9.150000
# max       16.190000
# Name: Ca, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Ba':
# count    213.000000
# mean       0.175869
# std        0.498245
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.150000
# Name: Ba, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Fe':
# count    213.000000
# mean       0.057277
# std        0.097589
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.100000
# max        0.510000
# Name: Fe, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'Type':
# count    213.000000
# mean       2.788732
# std        2.105130
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        7.000000
# Name: Type, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_11600\1391520814.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')

# %%
# Pie chart for 'Type'
df['Type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=['red', 'green', 'blue', 'orange', 'purple', 'cyan'],
    startangle=90,
    shadow=True,
    explode=[0.05]*df['Type'].nunique()
)

plt.ylabel('')  # Hides the y-label
plt.title('Customer Type Distribution')
plt.tight_layout()
plt.show()

# %%
# Type: Type of glass: (class attribute)
#  1 -- building_windows_float_processed
#  2 --building_windows_non_float_processed
#  3 --vehicle_windows_float_processed          #  Might strong
#  4 --vehicle_windows_non_float_processed (none in this database)
#  5 --containers  Weak
#  6 --tableware  Weak
#  7 --headlamps                            Stronger Galss

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.groupby('Type')['Si'].mean()
# Out:
# Type
# 1    72.631449
# 2    72.598026
# 3    72.404706
# 5    72.366154
# 6    73.206667
# 7    72.965862
# Name: Si, dtype: float64

# %%
df.groupby('Type')['Ca'].mean()
# Out:
# Type
# 1     8.786087
# 2     9.073684
# 3     8.782941
# 5    10.123846
# 6     9.356667
# 7     8.491379
# Name: Ca, dtype: float64

# %%
df.groupby('Type')['Mg'].mean()
# Out:
# Type
# 1    3.548551
# 2    3.002105
# 3    3.543529
# 5    0.773846
# 6    1.305556
# 7    0.538276
# Name: Mg, dtype: float64

# %%
df.groupby('Type')['Al'].mean()
# Out:
# Type
# 1    1.173913
# 2    1.408158
# 3    1.201176
# 5    2.033846
# 6    1.366667
# 7    2.122759
# Name: Al, dtype: float64

# %% [markdown]
# Higher values of these elements may indicate stronger glass:
#
# Si
#
# Al
#
# Ca
#
# Mg
#
# Higher values of these may indicate softer/weaker glass:
# Na
#
# K
#
# So, Si > Al > Ca > Mg are your best indicators of strong glass.

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,roc_auc_score,classification_report,roc_curve,auc
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Type',axis=1)
y=df['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=model.predict(X_test)
print(accuracy_score(y_test,prediction))
# Out:
# 0.75

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[16,  2,  0,  0,  0,  0],
#        [ 5, 16,  0,  3,  0,  0],
#        [ 2,  0,  2,  0,  0,  0],
#        [ 0,  1,  0,  3,  0,  0],
#        [ 0,  1,  0,  0,  2,  0],
#        [ 0,  2,  0,  0,  0,  9]])

# %%
Gb_model=GradientBoostingClassifier()
Gb_model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
prediction=Gb_model.predict(X_test)

print(accuracy_score(y_test,prediction))
# Out:
# 0.78125

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[15,  1,  1,  0,  0,  1],
#        [ 2, 19,  1,  2,  0,  0],
#        [ 1,  1,  2,  0,  0,  0],
#        [ 0,  2,  0,  2,  0,  0],
#        [ 0,  1,  0,  0,  2,  0],
#        [ 0,  1,  0,  0,  0, 10]])

# %% [markdown]
# ### Hyper ParaMetertuning in Random forest

# %%
model=RandomForestClassifier(n_estimators=500,max_samples=0.25,bootstrap=True,oob_score=True )

# %%
model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=model.predict(X_test)
print(accuracy_score(y_test,prediction))
# Out:
# 0.75

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300, 500],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False],
    'class_weight': [None, 'balanced', 'balanced_subsample'],
    'random_state': [42]  # Ensures reproducibility
}

# %%
rf = RandomForestClassifier()
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 7776 candidates, totalling 38880 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'class_weight': [None, 'balanced',
#                                           'balanced_subsample'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300, 500],
#                          'random_state': [42]},
#              scoring='accuracy', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'bootstrap': True, 'class_weight': None, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300, 'random_state': 42}

# %%
grid_search.best_score_
# Out:
# np.float64(0.7719540229885057)
