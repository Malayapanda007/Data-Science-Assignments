# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/91637/OneDrive/Desktop/EXCELAR ASSIGNMENT/12 EDA2/adult_with_headers.csv')

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# All The Column are in Currect format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df[df.duplicated()]
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (32537, 15)

# %%
# finding Null value in the data frame
for i in df.columns:
    print(i,df[i].isnull().sum())
# Out:
# age 0
# workclass 0
# fnlwgt 0
# education 0
# education_num 0
# marital_status 0
# occupation 0
# relationship 0
# race 0
# sex 0
# capital_gain 0
# capital_loss 0
# hours_per_week 0
# native_country 0
# income 0

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df['age'].mean()
# Out:
# np.float64(38.585548759873376)

# %%
df['age'].mode()
# Out:
# 0    36
# Name: age, dtype: int64

# %%
sns.boxplot(df['age'])
plt.show()

# %%
df['age'].plot(kind='hist', bins=30)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['income_encoded'] = le.fit_transform(df['income'])

# %%
df.head(1)
# Out:
#    age   workclass  fnlwgt   education  education_num  marital_status  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship    race    sex  capital_gain  capital_loss  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    hours_per_week  native_country  income  income_encoded
# 0              40   United-States   <=50K               0

# %%
nuemeric_col=df[['age','fnlwgt','education_num','capital_gain','capital_loss','hours_per_week','income_encoded']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Loop through each column in the DataFrame
for col in nuemeric_col.columns:
    # Print descriptive statistics
    print(f"Statistics for '{col}':")
    print(df[col].describe(), "\n")
    
    # Set up the figure with subplots for boxplot, KDE, histogram + KDE, and violin plot
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))  # Reduced figure size (1 row, 4 columns)

    # Box plot (1st plot)
    sns.boxplot(y=df[col], ax=axes[0], color='skyblue')
    axes[0].set_title(f'Box Plot of {col}')
    axes[0].set_ylabel(col)

    # KDE plot (2nd plot)
    sns.kdeplot(df[col], fill=True, ax=axes[1], color='salmon', linewidth=2)
    axes[1].set_title(f'KDE Plot of {col}')
    axes[1].set_xlabel(col)

    # Histogram with KDE (3rd plot)
    sns.histplot(df[col], bins=30, kde=True, ax=axes[2], color='teal')
    axes[2].set_title(f'Histogram + KDE of {col}')
    axes[2].set_xlabel(col)
    axes[2].grid(True, linestyle='--', alpha=0.5)

    # Violin plot (4th plot)
    sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
    axes[3].set_title(f'Violin Plot of {col}')
    axes[3].set_ylabel(col)

    # Adjust layout to make sure plots don't overlap
    plt.tight_layout()
    plt.show()
# Out:
# Statistics for 'age':
# count    32537.000000
# mean        38.585549
# std         13.637984
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_14964\604550504.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df[col], ax=axes[3], palette='Set2')
# Statistics for 'fnlwgt':
# count    3.253700e+04
# mean     1.897808e+05
# std      1.055565e+05
# min      1.228500e+04
# 25%      1.178270e+05
# 50%      1.783560e+05
# 75%      2.369930e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64
# C:\Users\91637\AppData\Local\Temp\ipykernel_14964\604550504.py:30: FutureWarning:
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income', 'income_encoded'],
#       dtype='object')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %% [markdown]
# ### EXTRA

# %%
edu_wc_counts = df.groupby('education')['workclass'].value_counts().reset_index(name='count')


edu_totals = df['education'].value_counts().to_dict()

edu_wc_counts['percentage'] = edu_wc_counts.apply(
    lambda row: round((row['count'] / edu_totals[row['education']]) * 100, 2), axis=1
)

print(edu_wc_counts)
# Out:
#          education          workclass  count  percentage
# 0             10th            Private    695       74.49
# 1             10th                  ?    100       10.72
# 2             10th   Self-emp-not-inc     67        7.18
# 3             10th          Local-gov     31        3.32
# 4             10th       Self-emp-inc     19        2.04
# ..             ...                ...    ...         ...
# 112   Some-college          State-gov    325        4.46
# 113   Some-college        Federal-gov    254        3.49
# 114   Some-college       Self-emp-inc    226        3.10
# 115   Some-college        Without-pay      3        0.04
# 116   Some-college       Never-worked      2        0.03
#
# [117 rows x 4 columns]

# %%
edu_wc_counts['education'].unique()
# Out:
# array([' 10th', ' 11th', ' 12th', ' 1st-4th', ' 5th-6th', ' 7th-8th',
#        ' 9th', ' Assoc-acdm', ' Assoc-voc', ' Bachelors', ' Doctorate',
#        ' HS-grad', ' Masters', ' Preschool', ' Prof-school',
#        ' Some-college'], dtype=object)

# %%
edu_wc_counts[edu_wc_counts['education']==' 10th'].iloc[0]
# Out:
# education         10th
# workclass      Private
# count              695
# percentage       74.49
# Name: 0, dtype: object

# %%
edu_wc_counts[edu_wc_counts['education']==' 11th'].iloc[0]
# Out:
# education         11th
# workclass      Private
# count              923
# percentage       78.55
# Name: 8, dtype: object

# %%
edu_wc_counts[edu_wc_counts['education']==' 12th'].iloc[0]
# Out:
# education         12th
# workclass      Private
# count              333
# percentage       76.91
# Name: 16, dtype: object

# %%
# 1st-4th
print("\nEducation Level: 1st-4th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 1st-4th'][['workclass', 'count', 'percentage']])

# 5th-6th
print("\nEducation Level: 5th-6th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 5th-6th'][['workclass', 'count', 'percentage']])

# 7th-8th
print("\nEducation Level: 7th-8th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 7th-8th'][['workclass', 'count', 'percentage']])

# 9th
print("\nEducation Level: 9th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 9th'][['workclass', 'count', 'percentage']])

# Assoc-acdm
print("\nEducation Level: Assoc-acdm")
print(edu_wc_counts[edu_wc_counts['education'] == ' Assoc-acdm'][['workclass', 'count', 'percentage']])

# Assoc-voc
print("\nEducation Level: Assoc-voc")
print(edu_wc_counts[edu_wc_counts['education'] == ' Assoc-voc'][['workclass', 'count', 'percentage']])

# Bachelors
print("\nEducation Level: Bachelors")
print(edu_wc_counts[edu_wc_counts['education'] == ' Bachelors'][['workclass', 'count', 'percentage']])

# Doctorate
print("\nEducation Level: Doctorate")
print(edu_wc_counts[edu_wc_counts['education'] == ' Doctorate'][['workclass', 'count', 'percentage']])

# HS-grad
print("\nEducation Level: HS-grad")
print(edu_wc_counts[edu_wc_counts['education'] == ' HS-grad'][['workclass', 'count', 'percentage']])

# Masters
print("\nEducation Level: Masters")
print(edu_wc_counts[edu_wc_counts['education'] == ' Masters'][['workclass', 'count', 'percentage']])

# Preschool
print("\nEducation Level: Preschool")
print(edu_wc_counts[edu_wc_counts['education'] == ' Preschool'][['workclass', 'count', 'percentage']])

# Prof-school
print("\nEducation Level: Prof-school")
print(edu_wc_counts[edu_wc_counts['education'] == ' Prof-school'][['workclass', 'count', 'percentage']])

# 12th
print("\nEducation Level: 12th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 12th'][['workclass', 'count', 'percentage']])
# Out:
# Education Level: 1st-4th
#             workclass  count  percentage
# 23            Private    134       80.72
# 24   Self-emp-not-inc     13        7.83
# 25                  ?     12        7.23
# 26          Local-gov      4        2.41
# 27       Self-emp-inc      2        1.20
# 28          State-gov      1        0.60
#
# Education Level: 5th-6th
#             workclass  count  percentage
# 29            Private    265       79.82
# 30                  ?     30        9.04
# 31   Self-emp-not-inc     19        5.72
# 32          Local-gov      9        2.71
# 33       Self-emp-inc      4        1.20
# 34          State-gov      4        1.20
# 35        Federal-gov      1        0.30
#
# Education Level: 7th-8th
#             workclass  count  percentage
# 36            Private    423       65.58
# 37   Self-emp-not-inc     94       14.57
# 38                  ?     72       11.16
# 39          Local-gov     28        4.34
# 40       Self-emp-inc     14        2.17
# ...

# %% [markdown]
# ### REmainind

# %%
df[df['workclass'] ==' ?']
# Out:
#        age workclass  fnlwgt      education  education_num  \
# 27      54         ?  180211   Some-college             10
# 61      32         ?  293936        7th-8th              4
# 69      25         ?  200681   Some-college             10
# 77      67         ?  212759           10th              6
# 106     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32530   35         ?  320084      Bachelors             13
# 32531   30         ?   33811      Bachelors             13
# 32539   71         ?  287372      Doctorate             16
# 32541   41         ?  202822        HS-grad              9
# 32542   72         ?  129912        HS-grad              9
#
#                marital_status occupation    relationship                 race  \
# 27         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
## 5.64 Data in in '?' in this format we have to handel this 
(1836/32537)*100
# Out:
# 5.6428066508897565

# %%
df['workclass'].mode()
# Out:
# 0     Private
# Name: workclass, dtype: object

# %%
workclass_map = {
    ' Private': 'Private',
    ' Self-emp-not-inc': 'Self-Employed',
    ' Self-emp-inc': 'Self-Employed',
    ' Federal-gov': 'Government',
    ' State-gov': 'Government',
    ' Local-gov': 'Government',
    ' Without-pay': 'Not Working',
    ' Never-worked': 'Not Working',
    ' ?': 'Private'
}
df['workclass_grouped'] = df['workclass'].map(workclass_map)

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df['workclass_grouped'].unique()
# Out:
# array(['Government', 'Self-Employed', 'Private', 'Not Working'],
#       dtype=object)

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
education_map = {
    ' Preschool': 'Low',
    ' 1st-4th': 'Low',
    ' 5th-6th': 'Low',
    ' 7th-8th': 'Low',
    ' 9th': 'Low',
    ' 10th': 'Low',
    ' 11th': 'Low',
    ' 12th': 'Low',
    ' HS-grad': 'Medium',
    ' Some-college': 'Medium',
    ' Assoc-voc': 'Medium',
    ' Assoc-acdm': 'Medium',
    ' Bachelors': 'High',
    ' Masters': 'High',
    ' Prof-school': 'High',
    ' Doctorate': 'High'
}

df['education_level'] = df['education'].map(education_map)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %%
df['marital_status'].value_counts()
# Out:
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
marital_map = {
    ' Married-civ-spouse': 'Married',
    ' Married-AF-spouse': 'Married',
    ' Never-married': 'Single',
    ' Divorced': 'Not-Married',
    ' Separated': 'Not-Married',
    ' Widowed': 'Not-Married',
    ' Married-spouse-absent': 'Not-Married'
}

df['marital_status_grouped'] = df['marital_status'].map(marital_map)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %%
edu_wc_counts = df.groupby('education')['occupation'].value_counts().reset_index(name='count')


edu_totals = df['education'].value_counts().to_dict()

edu_wc_counts['percentage'] = edu_wc_counts.apply(
    lambda row: round((row['count'] / edu_totals[row['education']]) * 100, 2), axis=1
)
print(edu_wc_counts)
# Out:
#          education          occupation  count  percentage
# 0             10th       Other-service    194       20.79
# 1             10th        Craft-repair    170       18.22
# 2             10th                   ?    102       10.93
# 3             10th   Machine-op-inspct    101       10.83
# 4             10th    Transport-moving     84        9.00
# ..             ...                 ...    ...         ...
# 212   Some-college   Handlers-cleaners    267        3.67
# 213   Some-college     Protective-serv    202        2.77
# 214   Some-college     Farming-fishing    174        2.39
# 215   Some-college     Priv-house-serv     16        0.22
# 216   Some-college        Armed-Forces      2        0.03
#
# [217 rows x 4 columns]

# %%
edu_wc_counts[edu_wc_counts['education']==' 10th'].iloc[0]
# Out:
# education               10th
# occupation     Other-service
# count                    194
# percentage             20.79
# Name: 0, dtype: object

# %%
edu_wc_counts[edu_wc_counts['education']==' 11th'].iloc[0]
# Out:
# education               11th
# occupation     Other-service
# count                    238
# percentage             20.26
# Name: 14, dtype: object

# %%
edu_wc_counts[edu_wc_counts['education']==' 12th'].iloc[0]
# Out:
# education               12th
# occupation     Other-service
# count                     85
# percentage             19.63
# Name: 28, dtype: object

# %%
# 1st-4th
print("\nEducation Level: 1st-4th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 1st-4th'].iloc[0])

# 5th-6th
print("\nEducation Level: 5th-6th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 5th-6th'].iloc[0])

# 7th-8th
print("\nEducation Level: 7th-8th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 7th-8th'].iloc[0])

# 9th
print("\nEducation Level: 9th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 9th'].iloc[0])

# Assoc-acdm
print("\nEducation Level: Assoc-acdm")
print(edu_wc_counts[edu_wc_counts['education'] == ' Assoc-acdm'].iloc[0])

# Assoc-voc
print("\nEducation Level: Assoc-voc")
print(edu_wc_counts[edu_wc_counts['education'] == ' Assoc-voc'].iloc[0])

# Bachelors
print("\nEducation Level: Bachelors")
print(edu_wc_counts[edu_wc_counts['education'] == ' Bachelors'].iloc[0])

# Doctorate
print("\nEducation Level: Doctorate")
print(edu_wc_counts[edu_wc_counts['education'] == ' Doctorate'].iloc[0])

# HS-grad
print("\nEducation Level: HS-grad")
print(edu_wc_counts[edu_wc_counts['education'] == ' HS-grad'].iloc[0])

# Masters
print("\nEducation Level: Masters")
print(edu_wc_counts[edu_wc_counts['education'] == ' Masters'].iloc[0])

# Preschool
print("\nEducation Level: Preschool")
print(edu_wc_counts[edu_wc_counts['education'] == ' Preschool'].iloc[0])

# Prof-school
print("\nEducation Level: Prof-school")
print(edu_wc_counts[edu_wc_counts['education'] == ' Prof-school'].iloc[0])

# 12th
print("\nEducation Level: 12th")
print(edu_wc_counts[edu_wc_counts['education'] == ' 12th'].iloc[0])
# Out:
# Education Level: 1st-4th
# education            1st-4th
# occupation     Other-service
# count                     40
# percentage              24.1
# Name: 43, dtype: object
#
# Education Level: 5th-6th
# education            5th-6th
# occupation     Other-service
# count                     64
# percentage             19.28
# Name: 55, dtype: object
#
# Education Level: 7th-8th
# education           7th-8th
# occupation     Craft-repair
# count                   115
# percentage            17.83
# Name: 69, dtype: object
#
# Education Level: 9th
# education                9th
# occupation     Other-service
# count                    101
# percentage             19.65
# Name: 83, dtype: object
#
# Education Level: Assoc-acdm
# education        Assoc-acdm
# occupation     Adm-clerical
# count                   193
# percentage            18.09
# Name: 97, dtype: object
#
# Education Level: Assoc-voc
# education         Assoc-voc
# occupation     Craft-repair
# ...

# %%
# Data as a list of dictionaries
data = [
    {'education': '1st-4th', 'occupation': 'Other-service'},
    {'education': '5th-6th', 'occupation': 'Other-service'},
    {'education': '7th-8th', 'occupation': 'Craft-repair'},
    {'education': '9th', 'occupation': 'Other-service'},
    {'education': 'Assoc-acdm', 'occupation': 'Adm-clerical'},
    {'education': 'Assoc-voc', 'occupation': 'Craft-repair'},
    {'education': 'Bachelors', 'occupation': 'Prof-specialty'},
    {'education': 'Doctorate', 'occupation': 'Prof-specialty'},
    {'education': 'HS-grad', 'occupation': 'Craft-repair'},
    {'education': 'Masters', 'occupation': 'Prof-specialty'},
    {'education': 'Preschool', 'occupation': 'Other-service'},
    {'education': 'Prof-school', 'occupation': 'Prof-specialty'},
    {'education': '12th', 'occupation': 'Other-service'},
    {'education': '11th', 'occupation': 'Other-service'},
    {'education': '10th', 'occupation': 'Other-service'}
]

# Create DataFrame
edu_occ_df = pd.DataFrame(data)

# %%
edu_occ_df
# Out:
#       education      occupation
# 0       1st-4th   Other-service
# 1       5th-6th   Other-service
# 2       7th-8th    Craft-repair
# 3           9th   Other-service
# 4    Assoc-acdm    Adm-clerical
# 5     Assoc-voc    Craft-repair
# 6     Bachelors  Prof-specialty
# 7     Doctorate  Prof-specialty
# 8       HS-grad    Craft-repair
# 9       Masters  Prof-specialty
# 10    Preschool   Other-service
# 11  Prof-school  Prof-specialty
# 12         12th   Other-service
# 13         11th   Other-service
# 14         10th   Other-service

# %%
df[df['occupation']== ' ?']
# Out:
#        age workclass  fnlwgt      education  education_num  \
# 27      54         ?  180211   Some-college             10
# 61      32         ?  293936        7th-8th              4
# 69      25         ?  200681   Some-college             10
# 77      67         ?  212759           10th              6
# 106     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32530   35         ?  320084      Bachelors             13
# 32531   30         ?   33811      Bachelors             13
# 32539   71         ?  287372      Doctorate             16
# 32541   41         ?  202822        HS-grad              9
# 32542   72         ?  129912        HS-grad              9
#
#                marital_status occupation    relationship                 race  \
# 27         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df.shape
# Out:
# (32537, 19)

# %%
df[df['occupation'].isnull()]['occupation'].shape
# Out:
# (0,)

# %%
df['occupation'].value_counts().sum()
# Out:
# np.int64(32537)

# %%
df['occupation'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df['occupation'].value_counts().sum()
# Out:
# np.int64(32537)

# %%
# Mapping of education to likely occupation
edu_occ_map = {
    ' 1st-4th': ' Other-service',
    ' 5th-6th': ' Other-service',
    ' 7th-8th': ' Craft-repair',
    ' 9th': ' Other-service',
    ' Assoc-acdm': ' Adm-clerical',
    ' Assoc-voc': ' Craft-repair',
    ' Bachelors': ' Prof-specialty',
    ' Doctorate': ' Prof-specialty',
    ' HS-grad': ' Craft-repair',
    ' Masters': ' Prof-specialty',
    ' Preschool': ' Other-service',
    ' Prof-school': ' Prof-specialty',
    ' 12th': ' Other-service',
    ' 11th': ' Other-service',
    ' 10th': ' Other-service'
}

# Replace only rows with occupation ' ?' using corresponding education
df.loc[df['occupation'] == ' ?', 'occupation'] = df.loc[df['occupation'] == ' ?', 'education'].map(edu_occ_map)

# %%
# Mapping of education to likely occupation
edu_occ_map = {
    ' 1st-4th': ' Other-service',
    ' 5th-6th': ' Other-service',
    ' 7th-8th': ' Craft-repair',
    ' 9th': ' Other-service',
    ' Assoc-acdm': ' Adm-clerical',
    ' Assoc-voc': ' Craft-repair',
    ' Bachelors': ' Prof-specialty',
    ' Doctorate': ' Prof-specialty',
    ' HS-grad': ' Craft-repair',
    ' Masters': ' Prof-specialty',
    ' Preschool': ' Other-service',
    ' Prof-school': ' Prof-specialty',
    ' 12th': ' Other-service',
    ' 11th': ' Other-service',
    ' 10th': ' Other-service'
}

# # Replace ' ?' in occupation
# mask_question = df['occupation'] == ' ?'
# df.loc[mask_question, 'occupation'] = df.loc[mask_question, 'education'].map(edu_occ_map)

# Replace NaN in occupation
mask_nan = df['occupation'].isna()
df.loc[mask_nan, 'occupation'] = df.loc[mask_nan, 'education'].map(edu_occ_map)

# %%
df[df['occupation']== 'nan']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, native_country, income, income_encoded, workclass_grouped, education_level, marital_status_grouped]
# Index: []

# %%
df['occupation'].isnull().sum()
# Out:
# np.int64(516)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', nan, ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', nan, ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
# [' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df.shape
# Out:
# (32537, 19)

# %%
4761-4136
# Out:
# 625

# %%
4390-4094
# Out:
# 296

# %%
3815-3768
# Out:
# 47

# %%
3650-3291
625+296+47+359
# Out:
# 1327

# %%
1843-1327
# Out:
# 516

# %%
df['occupation'].value_counts()
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Out:
# occupation
# Craft-repair         4761
# Prof-specialty       4390
# Exec-managerial      4065
# Adm-clerical         3815
# Sales                3650
# Other-service        3650
# Machine-op-inspct    2000
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %%
# Mapping of education to likely occupation
edu_occ_map = {
    ' 1st-4th': ' Other-service',
    ' 5th-6th': ' Other-service',
    ' 7th-8th': ' Craft-repair',
    ' 9th': ' Other-service',
    ' Assoc-acdm': ' Adm-clerical',
    ' Assoc-voc': ' Craft-repair',
    ' Bachelors': ' Prof-specialty',
    ' Doctorate': ' Prof-specialty',
    ' HS-grad': ' Craft-repair',
    ' Masters': ' Prof-specialty',
    ' Preschool': ' Other-service',
    ' Prof-school': ' Prof-specialty',
    ' 12th': ' Other-service',
    ' 11th': ' Other-service',
    ' 10th': ' Other-service',
    ' Some-college': ' Craft-repair'  # Add this if not already present
}

# Replace only NaN values in occupation using the education mapping
df.loc[df['occupation'].isna(), 'occupation'] = df.loc[df['occupation'].isna(), 'education'].map(edu_occ_map)

# %%
df['occupation'].shape
# Out:
# (32537,)

# %%
df['occupation'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
occupation_map = {
    ' Prof-specialty': 'White-Collar',
    ' Exec-managerial': 'White-Collar',
    ' Adm-clerical': 'White-Collar',
    ' Sales': 'White-Collar',
    ' Tech-support': 'White-Collar',
    
    ' Craft-repair': 'Blue-Collar',
    ' Machine-op-inspct': 'Blue-Collar',
    ' Transport-moving': 'Blue-Collar',
    ' Handlers-cleaners': 'Blue-Collar',
    ' Farming-fishing': 'Blue-Collar',
    ' Protective-serv': 'Blue-Collar',
    
    ' Other-service': 'Service',
    ' Priv-house-serv': 'Service',
    
    ' Armed-Forces': 'Military',
    ' ?': 'Unknown'
}

df['occupation_grouped'] = df['occupation'].map(occupation_map)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %%
df['relationship'].value_counts()
# Out:
# relationship
# Husband           13187
# Not-in-family      8292
# Own-child          5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
df['race'].value_counts()
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
relationship_map = {
    ' Husband': 'Spouse',
    ' Wife': 'Spouse',
    ' Own-child': 'Child',
    ' Not-in-family': 'Not-in-family',
    ' Unmarried': 'Other',
    ' Other-relative': 'Other'
}

df['relationship_grouped'] = df['relationship'].map(relationship_map)

# %%
df['sex']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#           ...
# 32556     Female
# 32557       Male
# 32558     Female
# 32559       Male
# 32560     Female
# Name: sex, Length: 32537, dtype: object

# %%
df['sex'] = le.fit_transform(df['sex'])

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  sex  \
# 0            Never-married        Adm-clerical   Not-in-family   White    1
# ...

# %%
df.shape
# Out:
# (32537, 21)

# %%
df['sex'].value_counts().plot(kind='bar', color=['red', 'green', 'blue', 'orange', 'purple', 'cyan'])

plt.title('Distribution of Customer Types')
plt.xlabel('sex')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['native_country'].value_counts()
# Out:
# native_country
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        62
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
# Mapping of countries to regions
country_region_map = {
    ' United-States': 'North America',
    ' Canada': 'North America',
    ' Mexico': 'Latin America',
    ' Puerto-Rico': 'Latin America',
    ' El-Salvador': 'Latin America',
    ' Guatemala': 'Latin America',
    ' Honduras': 'Latin America',
    ' Nicaragua': 'Latin America',
    ' Columbia': 'Latin America',
    ' Ecuador': 'Latin America',
    ' Peru': 'Latin America',
    ' Trinadad&Tobago': 'Latin America',
    ' Jamaica': 'Latin America',
    ' Cuba': 'Latin America',
    
    ' South': 'Other',
    ' ?': 'Other',
    ' Outlying-US(Guam-USVI-etc)': 'Other',
    
    ' England': 'Europe',
    ' Germany': 'Europe',
    ' Italy': 'Europe',
    ' Poland': 'Europe',
    ' Portugal': 'Europe',
    ' France': 'Europe',
    ' Greece': 'Europe',
    ' Ireland': 'Europe',
    ' Hungary': 'Europe',
    ' Scotland': 'Europe',
    ' Yugoslavia': 'Europe',
    ' Holand-Netherlands': 'Europe',

    ' China': 'Asia',
    ' India': 'Asia',
    ' Iran': 'Asia',
    ' Japan': 'Asia',
    ' Cambodia': 'Asia',
    ' Vietnam': 'Asia',
    ' Laos': 'Asia',
    ' Philippines': 'Asia',
    ' Thailand': 'Asia',
    ' Taiwan': 'Asia',
    ' Hong': 'Asia',

    ' Dominican-Republic': 'Latin America',
    ' Haiti': 'Latin America'
}

# Create a new column for region
df['region'] = df['native_country'].map(country_region_map)

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64

# %%
nuemeric_col
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        income_encoded
# ...

# %%
corr_matrix = nuemeric_col.corr()

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar_kws={'shrink': 0.8})

# Add title
plt.title('Correlation Heatmap', fontsize=16)

# Display the heatmap
plt.tight_layout()
plt.show()

# %%
nuemeric_col.corr()['income_encoded'].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # NoW Data In Currect Format

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race  sex  ...  \
# 0        Never-married        Adm-clerical   Not-in-family   White    1  ...
# 1   Married-civ-spouse     Exec-managerial         Husband   White    1  ...
# 2             Divorced   Handlers-cleaners   Not-in-family   White    1  ...
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    1  ...
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    0  ...
#
#    hours_per_week  native_country  income income_encoded workclass_grouped  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income', 'income_encoded', 'workclass_grouped', 'education_level',
#        'marital_status_grouped', 'occupation_grouped', 'relationship_grouped',
#        'region'],
#       dtype='object')

# %%
df.drop(['fnlwgt', 'workclass', 'marital_status','occupation','relationship','education','native_country','income'], axis=1,inplace=True)

# %%
df['income']=df['income_encoded']

# %%
df.drop(['income_encoded'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    age  education_num    race  sex  capital_gain  capital_loss  \
# 0   39             13   White    1          2174             0
# 1   50             13   White    1             0             0
# 2   38              9   White    1             0             0
# 3   53              7   Black    1             0             0
# 4   28             13   Black    0             0             0
#
#    hours_per_week workclass_grouped education_level marital_status_grouped  \
# 0              40        Government            High                 Single
# 1              13     Self-Employed            High                Married
# 2              40           Private          Medium            Not-Married
# 3              40           Private             Low                Married
# 4              40           Private            High                Married
#
#   occupation_grouped relationship_grouped         region  income
# 0       White-Collar        Not-in-family  North America       0
# ...

# %%
df.shape
# Out:
# (32537, 14)

# %%
df.isnull().sum()
# Out:
# age                       0
# education_num             0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# workclass_grouped         0
# education_level           0
# marital_status_grouped    0
# occupation_grouped        0
# relationship_grouped      0
# region                    0
# income                    0
# dtype: int64

# %%
df.drop('race',axis=1,inplace= True)

# %%
df.head()
# Out:
#    age  education_num  sex  capital_gain  capital_loss  hours_per_week  \
# 0   39             13    1          2174             0              40
# 1   50             13    1             0             0              13
# 2   38              9    1             0             0              40
# 3   53              7    1             0             0              40
# 4   28             13    0             0             0              40
#
#   workclass_grouped education_level marital_status_grouped occupation_grouped  \
# 0        Government            High                 Single       White-Collar
# 1     Self-Employed            High                Married       White-Collar
# 2           Private          Medium            Not-Married        Blue-Collar
# 3           Private             Low                Married        Blue-Collar
# 4           Private            High                Married       White-Collar
#
#   relationship_grouped         region  income
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_cols = df.select_dtypes(include=['object', 'category']).columns
df_ordinal = df.copy()
ordinal_encoder = OrdinalEncoder()
df_ordinal[categorical_cols] = ordinal_encoder.fit_transform(df_ordinal[categorical_cols])
df_ordinal = df_ordinal.astype(int)

# %%
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
categorical_cols
# Out:
# Index(['workclass_grouped', 'education_level', 'marital_status_grouped',
#        'occupation_grouped', 'relationship_grouped', 'region'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
df = df.astype(int)

# %%
df
# Out:
#        age  education_num  sex  capital_gain  capital_loss  hours_per_week  \
# 0       39             13    1          2174             0              40
# 1       50             13    1             0             0              13
# 2       38              9    1             0             0              40
# 3       53              7    1             0             0              40
# 4       28             13    0             0             0              40
# ...    ...            ...  ...           ...           ...             ...
# 32556   27             12    0             0             0              38
# 32557   40              9    1             0             0              40
# 32558   58              9    0             0             0              40
# 32559   22              9    1             0             0              20
# 32560   52              9    0         15024             0              40
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'education_num', 'sex', 'capital_gain', 'capital_loss',
#        'hours_per_week', 'income', 'workclass_grouped_Not Working',
#        'workclass_grouped_Private', 'workclass_grouped_Self-Employed',
#        'education_level_Low', 'education_level_Medium',
#        'marital_status_grouped_Not-Married', 'marital_status_grouped_Single',
#        'occupation_grouped_Military', 'occupation_grouped_Service',
#        'occupation_grouped_White-Collar', 'relationship_grouped_Not-in-family',
#        'relationship_grouped_Other', 'relationship_grouped_Spouse',
#        'region_Europe', 'region_Latin America', 'region_North America',
#        'region_Other'],
#       dtype='object')

# %%
corr_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar_kws={'shrink': 0.8})

# Add title
plt.title('Correlation Heatmap', fontsize=16)

# Display the heatmap
plt.tight_layout()
plt.show()

# %%
df.corr()['income']
# Out:
# age                                   0.234037
# education_num                         0.335272
# sex                                   0.215969
# capital_gain                          0.223336
# capital_loss                          0.150501
# hours_per_week                        0.229658
# income                                1.000000
# workclass_grouped_Not Working        -0.014317
# workclass_grouped_Private            -0.125504
# workclass_grouped_Self-Employed       0.105858
# education_level_Low                  -0.166267
# education_level_Medium               -0.175856
# marital_status_grouped_Not-Married   -0.177588
# marital_status_grouped_Single        -0.318285
# occupation_grouped_Military          -0.005049
# occupation_grouped_Service           -0.172317
# occupation_grouped_White-Collar       0.234170
# relationship_grouped_Not-in-family   -0.188299
# relationship_grouped_Other           -0.170088
# relationship_grouped_Spouse           0.448412
# ...

# %%
df_ordinal.corr()['income']
# Out:
# age                       0.234037
# education_num             0.335272
# sex                       0.215969
# capital_gain              0.223336
# capital_loss              0.150501
# hours_per_week            0.229658
# workclass_grouped        -0.010486
# education_level          -0.265255
# marital_status_grouped   -0.422902
# occupation_grouped        0.172808
# relationship_grouped      0.410256
# region                    0.005021
# income                    1.000000
# Name: income, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from  sklearn.linear_model      import LogisticRegression

from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,roc_auc_score,classification_report,roc_curve,auc
from sklearn.model_selection import train_test_split

# %%
x=df_ordinal.drop('income',axis=1)
y=df_ordinal['income']

# %%
# Split into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=34)

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.feature_importances_
# Out:
# array([0.2422132 , 0.09825384, 0.01847071, 0.1208576 , 0.03933604,
#        0.12620035, 0.03229563, 0.04499871, 0.10226046, 0.04219053,
#        0.1105868 , 0.02233614])

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.feature_importances_
# Out:
# array([0.18293524, 0.05098189, 0.01468062, 0.12832137, 0.04474673,
#        0.11510038, 0.0384965 , 0.10869458, 0.0075281 , 0.03629003,
#        0.24598068, 0.02624388])

# %%
gb=GradientBoostingClassifier()
gb.fit(X_train,y_train)
gb.feature_importances_
# Out:
# array([0.06035175, 0.1178033 , 0.00252461, 0.20173637, 0.0581377 ,
#        0.03845011, 0.00242238, 0.03895464, 0.04907419, 0.07868194,
#        0.35034618, 0.00151684])

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
lr.coef_
# Out:
# C:\Users\91637\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[ 3.91539075e-03,  7.29612243e-02,  1.52861122e-01,
#          3.05738569e-04,  6.94832614e-04,  1.95878272e-02,
#         -5.22090900e-02, -5.78395173e-01, -1.41456340e+00,
#          2.52102675e-01,  4.85741092e-02, -5.66331057e-01]])

# %%
lr.coef_.flatten()
# Out:
# array([ 3.91539075e-03,  7.29612243e-02,  1.52861122e-01,  3.05738569e-04,
#         6.94832614e-04,  1.95878272e-02, -5.22090900e-02, -5.78395173e-01,
#        -1.41456340e+00,  2.52102675e-01,  4.85741092e-02, -5.66331057e-01])

# %%
corr_df = df_ordinal.corr()['income'].reset_index()
corr_df.columns = ['Feature', ' corr Feature']
corr_df.drop(index=12, inplace=True)

print(corr_df)
# Out:
#                    Feature   corr Feature
# 0                      age       0.234037
# 1            education_num       0.335272
# 2                      sex       0.215969
# 3             capital_gain       0.223336
# 4             capital_loss       0.150501
# 5           hours_per_week       0.229658
# 6        workclass_grouped      -0.010486
# 7          education_level      -0.265255
# 8   marital_status_grouped      -0.422902
# 9       occupation_grouped       0.172808
# 10    relationship_grouped       0.410256
# 11                  region       0.005021

# %%
corr_df['Rf feature imp']=rf.feature_importances_
corr_df['DT feature imp']=dt.feature_importances_
corr_df['GB feature imp']=gb.feature_importances_
corr_df['Lr feature imp']=lr.coef_.flatten()

# %%
corr_df
# Out:
#                    Feature   corr Feature  Rf feature imp  DT feature imp  \
# 0                      age       0.234037        0.242213        0.182935
# 1            education_num       0.335272        0.098254        0.050982
# 2                      sex       0.215969        0.018471        0.014681
# 3             capital_gain       0.223336        0.120858        0.128321
# 4             capital_loss       0.150501        0.039336        0.044747
# 5           hours_per_week       0.229658        0.126200        0.115100
# 6        workclass_grouped      -0.010486        0.032296        0.038496
# 7          education_level      -0.265255        0.044999        0.108695
# 8   marital_status_grouped      -0.422902        0.102260        0.007528
# 9       occupation_grouped       0.172808        0.042191        0.036290
# 10    relationship_grouped       0.410256        0.110587        0.245981
# 11                  region       0.005021        0.022336        0.026244
#
# ...

# %%
corr_df_numeric = corr_df.select_dtypes(include=['number'])  
corr_df['row_mean'] = corr_df_numeric.mean(axis=1)

# %%
corr_df
# Out:
#                    Feature   corr Feature  Rf feature imp  DT feature imp  \
# 0                      age       0.234037        0.242213        0.182935
# 1            education_num       0.335272        0.098254        0.050982
# 2                      sex       0.215969        0.018471        0.014681
# 3             capital_gain       0.223336        0.120858        0.128321
# 4             capital_loss       0.150501        0.039336        0.044747
# 5           hours_per_week       0.229658        0.126200        0.115100
# 6        workclass_grouped      -0.010486        0.032296        0.038496
# 7          education_level      -0.265255        0.044999        0.108695
# 8   marital_status_grouped      -0.422902        0.102260        0.007528
# 9       occupation_grouped       0.172808        0.042191        0.036290
# 10    relationship_grouped       0.410256        0.110587        0.245981
# 11                  region       0.005021        0.022336        0.026244
#
# ...

# %% [markdown]
# ### Drop these column  workclass_grouped,capital_loss,sex

# %%
after_drop=df_ordinal.drop(['workclass_grouped','capital_loss','sex'],axis=1)

# %%
x=after_drop.drop('income',axis=1)
y=after_drop['income']

# %%
# Split into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=34)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict=rf.predict(X_test)

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8345625896332719

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8345625896332719

# %% [markdown]
# ### Final Data Frame After  Everything

# %%
df.columns
# Out:
# Index(['age', 'education_num', 'sex', 'capital_gain', 'capital_loss',
#        'hours_per_week', 'income', 'workclass_grouped_Not Working',
#        'workclass_grouped_Private', 'workclass_grouped_Self-Employed',
#        'education_level_Low', 'education_level_Medium',
#        'marital_status_grouped_Not-Married', 'marital_status_grouped_Single',
#        'occupation_grouped_Military', 'occupation_grouped_Service',
#        'occupation_grouped_White-Collar', 'relationship_grouped_Not-in-family',
#        'relationship_grouped_Other', 'relationship_grouped_Spouse',
#        'region_Europe', 'region_Latin America', 'region_North America',
#        'region_Other'],
#       dtype='object')

# %%
df['education_level']=df_ordinal['education_level']

# %%
df.head()
# Out:
#    age  education_num  sex  capital_gain  capital_loss  hours_per_week  \
# 0   39             13    1          2174             0              40
# 1   50             13    1             0             0              13
# 2   38              9    1             0             0              40
# 3   53              7    1             0             0              40
# 4   28             13    0             0             0              40
#
#    income  workclass_grouped_Not Working  workclass_grouped_Private  \
# 0       0                              0                          0
# 1       0                              0                          0
# 2       0                              0                          1
# 3       0                              0                          1
# 4       0                              0                          1
#
#    workclass_grouped_Self-Employed  ...  occupation_grouped_Service  \
# ...

# %%
df=df.drop(['workclass_grouped_Not Working','workclass_grouped_Private','workclass_grouped_Self-Employed','education_level_Low', 'education_level_Medium'],axis=1)

# %% [markdown]
# #### Check with A Model

# %%
RandomForest=RandomForestClassifier()

# %%
x=df.drop('income',axis=1)
y=df['income']

# %%
# Split into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=34)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
RandomForest.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict=RandomForest.predict(X_test)

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8429625076828519

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[6736,  642],
#        [ 891, 1493]])

# %%
probability_pred=RandomForest.predict_proba(X_test)

# %%
probability_pred[:,1]
# Out:
# array([0.00333333, 0.        , 0.01      , ..., 0.        , 0.        ,
#        0.24122222])

# %%
fpr, tpr, thresholds = roc_curve(y_test,probability_pred[:,1])

# %%
j_scores = tpr - fpr
best_index = np.argmax(j_scores)
best_threshold = thresholds[best_index]

# Step 7: Print best threshold
print(f"Best Threshold (maximizing TPR - FPR): {best_threshold:.4f}")
print(f"True Positive Rate: {tpr[best_index]:.4f}")
print(f"False Positive Rate: {fpr[best_index]:.4f}")

# Step 8: Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, color='blue', label='ROC Curve')
plt.scatter(fpr[best_index], tpr[best_index], color='red', label=f'Best Threshold = {best_threshold:.4f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Best Threshold')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Best Threshold (maximizing TPR - FPR): 0.2137
# True Positive Rate: 0.8280
# False Positive Rate: 0.2097

# %%
optimal_idx = (tpr - fpr).argmax()
optimal_threshold = thresholds[optimal_idx]

print(f"Optimal Threshold: {optimal_threshold}")
# Out:
# Optimal Threshold: 0.21375

# %%
# Get probability predictions
probability_pred = RandomForest.predict_proba(X_test)

y_pred_threshold = (probability_pred[:, 1] >= 0.6).astype(int)

# %%
accuracy_score(y_test,y_pred_threshold)
# Out:
# 0.8447039541077648

# %%
confusion_matrix(y_test,y_pred_threshold)
# Out:
# array([[6924,  454],
#        [1062, 1322]])
